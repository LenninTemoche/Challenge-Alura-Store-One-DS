# %% [markdown]
# ### Importación de datos

# %%
#librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = "https://raw.githubusercontent.com/LenninTemoche/Challenge-Alura-Store-One-DS/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/LenninTemoche/Challenge-Alura-Store-One-DS/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/LenninTemoche/Challenge-Alura-Store-One-DS/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/LenninTemoche/Challenge-Alura-Store-One-DS/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda_1 = pd.read_csv(url)
tienda_2 = pd.read_csv(url2)
tienda_3 = pd.read_csv(url3)
tienda_4 = pd.read_csv(url4)

# %% [markdown]
# # Análisis exploratorio de datos

# %% [markdown]
# Se realiza el analisis de datos para el caso de estudio de Alura Store Latam.
#
# **Objetivo**: Identificar los tipos de datos, verificar valores nulos, duplicados y tipo correcto de datos de fecha.

# %%
# Análisis exploratorio de tienda_1
print("\nInformación concisa de tienda_1:")
tienda_1.info()

print("\nEstadísticas descriptivas de tienda_1:")
print(tienda_1.describe())

print("\nConteo de valores nulos por columna en tienda_1:")
print(tienda_1.isnull().sum())

print("\nNúmero de filas duplicadas en tienda_1:")
duplicados = tienda_1.duplicated().sum()
print(duplicados)

if duplicados > 0:
    print("Se encontraron filas duplicadas. Eliminando duplicados...")
    tienda_1.drop_duplicates(inplace=True)
    print("Número de filas después de eliminar duplicados:", tienda_1.shape[0])
else:
    print("No se encontraron filas duplicadas.")

# Convertir 'Fecha de Compra' a datetime para tienda_1
tienda_1['Fecha de Compra'] = pd.to_datetime(tienda_1['Fecha de Compra'], format='%d/%m/%Y', errors='coerce')
print("Tipo de dato de 'Fecha de Compra' en tienda_1 después de la conversión:")
print(tienda_1['Fecha de Compra'].dtype)
# Out:
# Información concisa de tienda_1:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB
#
# ...

# %%
tienda_1.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      2021-01-16      Pedro Gomez          Bogotá             4
# 1      2022-05-18  Beatriz Morales        Medellín             1
# 2      2021-03-15   Juan Fernandez       Cartagena             1
# 3      2022-05-03   Juan Fernandez            Cali             4
# 4      2020-11-07    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %%
# Análisis exploratorio de tienda_2
print("\nInformación concisa de tienda_2:")
tienda_2.info()

print("\nEstadísticas descriptivas de tienda_2:")
print(tienda_2.describe())

print("\nConteo de valores nulos por columna en tienda_2:")
print(tienda_2.isnull().sum())

print("\nNúmero de filas duplicadas en tienda_2:")
duplicados = tienda_2.duplicated().sum()
print(duplicados)

if duplicados > 0:
    print("Se encontraron filas duplicadas. Eliminando duplicados...")
    tienda_2.drop_duplicates(inplace=True)
    print("Número de filas después de eliminar duplicados:", tienda_2.shape[0])
else:
    print("No se encontraron filas duplicadas.")

# Convertir 'Fecha de Compra' a datetime para tienda_2
tienda_2['Fecha de Compra'] = pd.to_datetime(tienda_2['Fecha de Compra'], format='%d/%m/%Y', errors='coerce')
print("Tipo de dato de 'Fecha de Compra' en tienda_2 después de la conversión:")
print(tienda_2['Fecha de Compra'].dtype)
# Out:
# Información concisa de tienda_2:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB
#
# ...

# %%
# Análisis exploratorio de tienda_3
print("\nInformación concisa de tienda_3:")
tienda_3.info()

print("\nEstadísticas descriptivas de tienda_3:")
print(tienda_3.describe())

print("\nConteo de valores nulos por columna en tienda_3:")
print(tienda_3.isnull().sum())

print("\nNúmero de filas duplicadas en tienda_3:")
duplicados = tienda_3.duplicated().sum()
print(duplicados)

if duplicados > 0:
    print("Se encontraron filas duplicadas. Eliminando duplicados...")
    tienda_3.drop_duplicates(inplace=True)
    print("Número de filas después de eliminar duplicados:", tienda_3.shape[0])
else:
    print("No se encontraron filas duplicadas.")

# Convertir 'Fecha de Compra' a datetime para tienda_2
tienda_3['Fecha de Compra'] = pd.to_datetime(tienda_3['Fecha de Compra'], format='%d/%m/%Y', errors='coerce')
print("Tipo de dato de 'Fecha de Compra' en tienda_3 después de la conversión:")
print(tienda_3['Fecha de Compra'].dtype)
# Out:
# Información concisa de tienda_3:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2359 entries, 0 to 2358
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2359 non-null   object
#  1   Categoría del Producto  2359 non-null   object
#  2   Precio                  2359 non-null   float64
#  3   Costo de envío          2359 non-null   float64
#  4   Fecha de Compra         2359 non-null   object
#  5   Vendedor                2359 non-null   object
#  6   Lugar de Compra         2359 non-null   object
#  7   Calificación            2359 non-null   int64
#  8   Método de pago          2359 non-null   object
#  9   Cantidad de cuotas      2359 non-null   int64
#  10  lat                     2359 non-null   float64
#  11  lon                     2359 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.3+ KB
#
# ...

# %%
# Análisis exploratorio de tienda_4
print("\nInformación concisa de tienda_4:")
tienda_4.info()

print("\nEstadísticas descriptivas de tienda_4:")
print(tienda_4.describe())

print("\nConteo de valores nulos por columna en tienda_4:")
print(tienda_4.isnull().sum())

print("\nNúmero de filas duplicadas en tienda_4:")
duplicados = tienda_4.duplicated().sum()
print(duplicados)

if duplicados > 0:
    print("Se encontraron filas duplicadas. Eliminando duplicados...")
    tienda_4.drop_duplicates(inplace=True)
    print("Número de filas después de eliminar duplicados:", tienda_4.shape[0])
else:
    print("No se encontraron filas duplicadas.")

# Convertir 'Fecha de Compra' a datetime para tienda_4
tienda_4['Fecha de Compra'] = pd.to_datetime(tienda_4['Fecha de Compra'], format='%d/%m/%Y', errors='coerce')
print("Tipo de dato de 'Fecha de Compra' en tienda_4 después de la conversión:")
print(tienda_4['Fecha de Compra'].dtype)
# Out:
# Información concisa de tienda_4:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2358 entries, 0 to 2357
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Producto                2358 non-null   object
#  1   Categoría del Producto  2358 non-null   object
#  2   Precio                  2358 non-null   float64
#  3   Costo de envío          2358 non-null   float64
#  4   Fecha de Compra         2358 non-null   object
#  5   Vendedor                2358 non-null   object
#  6   Lugar de Compra         2358 non-null   object
#  7   Calificación            2358 non-null   int64
#  8   Método de pago          2358 non-null   object
#  9   Cantidad de cuotas      2358 non-null   int64
#  10  lat                     2358 non-null   float64
#  11  lon                     2358 non-null   float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 221.2+ KB
#
# ...

# %%
tiendas = {
    "Tienda 1": tienda_1,
    "Tienda 2": tienda_2,
    "Tienda 3": tienda_3,
    "Tienda 4": tienda_4
}
def resumen_eda(df, nombre_tienda):
    return {
        "Tienda": nombre_tienda,
        "Total Registros": df.shape[0],
        "Filas Duplicadas": df.duplicated().sum(),
        "Valores Nulos": df.isnull().sum().sum(),
        "Precio Promedio": round(df["Precio"].mean(), 2),
        "Precio Mínimo": df["Precio"].min(),
        "Precio Máximo": df["Precio"].max(),
        "Costo Envío Promedio": round(df["Costo de envío"].mean(), 2),
        "Costo Envío Mínimo": df["Costo de envío"].min(),
        "Costo Envío Máximo": df["Costo de envío"].max(),
        "Calificación Promedio": round(df["Calificación"].mean(), 2),
        "Calificación Mínima": df["Calificación"].min(),
        "Calificación Máxima": df["Calificación"].max(),
        "Productos Únicos": df["Producto"].nunique(),
        "Categorías Únicas": df["Categoría del Producto"].nunique(),
        "Vendedores Únicos": df["Vendedor"].nunique(),
        "Fecha Inicio": df["Fecha de Compra"].min(),
        "Fecha Fin": df["Fecha de Compra"].max(),
        "Tipo de Fecha": df["Fecha de Compra"].dtypes
    }
# Crear lista con resumen de cada tienda
all_eda_data = []
for nombre_tienda, df in tiendas.items():
    all_eda_data.append(resumen_eda(df, nombre_tienda))
# Crear DataFrame resumen
summary_df = pd.DataFrame(all_eda_data)

summary_df
# Out:
#      Tienda  Total Registros  Filas Duplicadas  Valores Nulos  \
# 0  Tienda 1             2359                 0              0
# 1  Tienda 2             2359                 0              0
# 2  Tienda 3             2359                 0              0
# 3  Tienda 4             2358                 0              0
#
#    Precio Promedio  Precio Mínimo  Precio Máximo  Costo Envío Promedio  \
# 0        487867.91         7600.0      2977000.0              26018.61
# 1        473227.43         7600.0      2953400.0              25216.24
# 2        465459.77         7600.0      2968200.0              24805.68
# 3        440362.89         7600.0      2902200.0              23459.46
#
#    Costo Envío Mínimo  Costo Envío Máximo  Calificación Promedio  \
# 0                 0.0            160800.0                   3.98
# 1                 0.0            162500.0                   4.04
# 2                 0.0            158400.0                   4.05
# ...

# %% [markdown]
# * El resumen del análisis exploratorio muestra 0 filas duplicadas, 0 valores nulos en todas las tiendas y tipo de datos correctos para las fechas.

# %% [markdown]
# # 1. Análisis de facturación

# %% [markdown]
# * Se genera la columna Precio Total, asumiendo que las columnas Precio y Costo de envío, representan el valor de la Cantidad de unidades vendidas por producto.

# %%
tienda_1['Precio Total'] = tienda_1['Precio'] + tienda_1['Costo de envío']
tienda_2['Precio Total'] = tienda_2['Precio'] + tienda_2['Costo de envío']
tienda_3['Precio Total'] = tienda_3['Precio'] + tienda_3['Costo de envío']
tienda_4['Precio Total'] = tienda_4['Precio'] + tienda_4['Costo de envío']

print("Columna 'Precio Total' creada para las cuatro tiendas")
# Out:
# Columna 'Precio Total' creada para las cuatro tiendas

# %%
# Calcular la facturación total por Tienda:
facturacion_total_tienda_1 = tienda_1['Precio Total'].sum()
facturacion_total_tienda_2 = tienda_2['Precio Total'].sum()
facturacion_total_tienda_3 = tienda_3['Precio Total'].sum()
facturacion_total_tienda_4 = tienda_4['Precio Total'].sum()

print(f"Facturación total para tienda_1: {facturacion_total_tienda_1}")
print(f"Facturación total para tienda_2: {facturacion_total_tienda_2}")
print(f"Facturación total para tienda_3: {facturacion_total_tienda_3}")
print(f"Facturación total para tienda_4: {facturacion_total_tienda_4}")
# Out:
# Facturación total para tienda_1: 1212258300.0
# Facturación total para tienda_2: 1175828600.0
# Facturación total para tienda_3: 1156536200.0
# Facturación total para tienda_4: 1093693100.0

# %%
custom_palette = [
    "#BAE43A",  # Verde  más alto
    "#3A62E4",  # Azul
    "#3ABFE4",  # Azul claro
    "#E85D3A"   # Naranja  mpas bajo
]
facturacion_total_df = pd.DataFrame({
    'Tienda': ['tienda_1', 'tienda_2', 'tienda_3', 'tienda_4'],
    'Facturación Total': [
        facturacion_total_tienda_1,
        facturacion_total_tienda_2,
        facturacion_total_tienda_3,
        facturacion_total_tienda_4
    ]
})

plt.figure(figsize=(10, 6))
sns.barplot(x='Tienda', y='Facturación Total', data=facturacion_total_df, palette= custom_palette, hue='Tienda', legend=False)
plt.title('Facturación Total por Tienda')
plt.xlabel('Tiendas')
plt.ylabel('Facturación Total')
plt.ticklabel_format(style='plain', axis='y') # Para evitar notación científica en el eje Y
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.savefig('imgs/facturacion_total_por_tienda.png') 
plt.show()

# %% [markdown]
# * En tema de ingresos de las cuatro tiendas, la tienda_1 obtuvo la facturación total más alta y la tienda_4 obtuvo la facturación total más baja

# %% [markdown]
# # 2. Ventas por categoría
#
# * Objetivo: obtener la cantidad de ventas por categoría en cada tienda

# %%
tiendas = {
    "Tienda 1": tienda_1,
    "Tienda 2": tienda_2,
    "Tienda 3": tienda_3,
    "Tienda 4": tienda_4
}
# Usamos groupby + size y luego unimos todo con concat
ventas_por_categoria_df = pd.concat(
    {
        tienda: df.groupby("Categoría del Producto").size()
        for tienda, df in tiendas.items()
    },
    axis=1
).fillna(0).astype(int)
# Creamos la columna Total por Categoría
ventas_por_categoria_df["Total por Categoría"] = ventas_por_categoria_df.sum(axis=1)
# Ordenamos por total para el análisis
ventas_por_categoria_df = ventas_por_categoria_df.sort_values(
    by="Total por Categoría",
    ascending=False
)
# reseteamos indice y renombramos columna Categoría del Producto
ventas_por_categoria_df = ventas_por_categoria_df.reset_index()
ventas_por_categoria_df.rename(
    columns={"Categoría del Producto": "Categoría de Productos"},
    inplace=True
)

# %%
display(ventas_por_categoria_df)
# Out:
#     Categoría de Productos  Tienda 1  Tienda 2  Tienda 3  Tienda 4  \
# 0                  Muebles       465       442       499       480
# 1             Electrónicos       448       422       451       451
# 2                 Juguetes       324       313       315       338
# 3        Electrodomésticos       312       305       278       254
# 4     Deportes y diversión       284       275       277       277
# 5   Instrumentos musicales       182       224       177       170
# 6                   Libros       173       197       185       187
# 7  Artículos para el hogar       171       181       177       201
#
#    Total por Categoría
# 0                 1886
# 1                 1772
# 2                 1290
# 3                 1149
# 4                 1113
# 5                  753
# 6                  742
# 7                  730

# %%
# Graficamos con un Heatmap
heatmap_data = ventas_por_categoria_df.set_index(
    "Categoría de Productos"
)[["Tienda 1", "Tienda 2", "Tienda 3", "Tienda 4"]]
plt.figure(figsize=(12, 8))

sns.heatmap(
    heatmap_data,
    annot=True,
    fmt="d",
    cmap="YlGnBu",
    linewidths=0.5,
    cbar_kws={"label": "Cantidad de Ventas"}
)

plt.title("Heatmap de Ventas por Categoría y Tienda", fontsize=14)
plt.xlabel("Tiendas")
plt.ylabel("Categoría de Productos")
plt.tight_layout()
plt.savefig("imgs/heatmap_ventas_por_categoria_y_tienda.png")
plt.show()

# %% [markdown]
# ### Resultados Clave de Ventas por Categoría:
#
# *   **Tienda 3 Lidera en Muebles**: 'tienda_3' registra la mayor cantidad de ventas en la categoría 'Muebles' (499 unidades), seguida de cerca por 'tienda_4'. 'tienda_1' también tiene un buen desempeño en esta categoría.
# *   **Consistencia en Electrónicos**: Las ventas de 'Electrónicos' son bastante uniformes entre 'tienda_1', 'tienda_3' y 'tienda_4', con 'tienda_2' ligeramente por debajo. Esto sugiere una distribución equitativa de la demanda o una competencia similar en esta categoría.
# *   **Juguetes en Tienda 4**: 'tienda_4' se destaca ligeramente en la categoría 'Juguetes' con el mayor número de ventas (338 unidades).
# *   **Electrodomésticos: Tienda 1 a la Cabeza**: 'tienda_1' muestra el mayor volumen de ventas en 'Electrodomésticos' (312 unidades), mientras que 'tienda_4' tiene el más bajo (254 unidades), lo que podría indicar una oportunidad de mejora o una diferencia en la oferta de productos en esta última.
# *   **Artículos para el hogar**: 'tienda_4' lidera en 'Artículos para el hogar' con 201 ventas, mostrando un patrón diferente a las otras tiendas donde esta categoría es menor.

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
calificacion_promedio = {}
for i, tienda_df in enumerate([tienda_1, tienda_2, tienda_3, tienda_4]):
    store_name = f'tienda_{i+1}'
    calificacion_promedio[store_name] = tienda_df['Calificación'].mean().round(2)

calificacion_promedio_df = pd.DataFrame(list(calificacion_promedio.items()), columns=['Tienda', 'Calificación Promedio'])

print("Calificación Promedio por Tienda:")
display(calificacion_promedio_df)
# Out:
# Calificación Promedio por Tienda:
#      Tienda  Calificación Promedio
# 0  tienda_1                   3.98
# 1  tienda_2                   4.04
# 2  tienda_3                   4.05
# 3  tienda_4                   4.00

# %%
custom_palette = [
    "#E85D3A",  # Naranja  mpas bajo   
    "#3A62E4",  # Azul
    "#BAE43A",  # Verde  más alto
    "#3ABFE4" # Azul claro     
    
]
plt.figure(figsize=(10, 6))
bars = plt.bar(calificacion_promedio_df['Tienda'], calificacion_promedio_df['Calificación Promedio'], color=custom_palette, alpha=0.9)

# Ajustar eje Y para ver mejor las diferencias (ej. de 3.5 a 4.5)
plt.ylim(3.8, 4.2)
plt.title('Promedio de Calificación de Clientes por Tienda', fontsize=16)
plt.xlabel('Tienda', fontsize=12)
plt.ylabel('Calificación Promedio (1-5)', fontsize=12)

# Añadir etiquetas
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 0.005, f'{yval:.2f}', ha='center', va='bottom', fontweight='bold')

plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.xticks(rotation=45)
plt.savefig('imgs/calificacion_promedio_por_tienda.png')
plt.show()

# %% [markdown]
# ## Calificación promedio de los últimos 12 meses

# %%
#Dataframe consolidado
tiendas_dfs = {
    'tienda_1': tienda_1,
    'tienda_2': tienda_2,
    'tienda_3': tienda_3,
    'tienda_4': tienda_4
}

# Add 'Tienda' column to each DataFrame and collect them in a list
lista_dfs_para_concatenar = []
for nombre_tienda, df in tiendas_dfs.items():
    df_copy = df.copy() # Create a copy to avoid modifying original DataFrames directly if they are used later
    df_copy['Tienda'] = nombre_tienda
    lista_dfs_para_concatenar.append(df_copy)

# Concatenate all DataFrames
df_consolidado = pd.concat(lista_dfs_para_concatenar, ignore_index=True)

# Create 'Mes-Año' column
df_consolidado['Mes-Año'] = df_consolidado['Fecha de Compra'].dt.strftime('%Y-%m')

print("DataFrame consolidado (df_consolidado) creado con éxito.")
print(f"Dimensiones de df_consolidado: {df_consolidado.shape}")
print("Primeras 5 filas de df_consolidado:")
display(df_consolidado.head())
# Out:
# DataFrame consolidado (df_consolidado) creado con éxito.
# Dimensiones de df_consolidado: (9435, 15)
# Primeras 5 filas de df_consolidado:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      2021-01-16      Pedro Gomez          Bogotá             4
# 1      2022-05-18  Beatriz Morales        Medellín             1
# 2      2021-03-15   Juan Fernandez       Cartagena             1
# 3      2022-05-03   Juan Fernandez            Cali             4
# 4      2020-11-07    Maria Alfonso        Medellín             5
#
# ...

# %%
calificacion_mensual = df_consolidado.groupby(['Mes-Año', 'Tienda'])['Calificación'].mean().reset_index()

calificacion_mensual['Mes-Año'] = pd.to_datetime(calificacion_mensual['Mes-Año'])
calificacion_mensual = calificacion_mensual.sort_values(by='Mes-Año')

# Filter for the last 12 unique months
latest_month = calificacion_mensual['Mes-Año'].max()
start_date_12_months = latest_month - pd.DateOffset(months=11) # To include the latest month, we go back 11 months
calificacion_mensual_last_12 = calificacion_mensual[calificacion_mensual['Mes-Año'] >= start_date_12_months]

plt.figure(figsize=(14, 7))
sns.lineplot(data=calificacion_mensual_last_12, x='Mes-Año', y='Calificación', hue='Tienda', marker='o')
plt.title('Tendencia de Calificación Promedio Mensual por Tienda (Últimos 12 Meses)', fontsize=16)
plt.xlabel('Mes-Año', fontsize=12)
plt.ylabel('Calificación Promedio (1-5)', fontsize=12)
plt.ylim(1, 5) # Set y-axis limit to the rating scale
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(title='Tienda')
plt.tight_layout()
plt.savefig('imgs/Tendencia_Calificacion_promedio_12m')
plt.show()

print("DataFrame de calificación promedio mensual (últimos 12 meses):")
display(calificacion_mensual_last_12.tail())
# Out:
# DataFrame de calificación promedio mensual (últimos 12 meses):
#        Mes-Año    Tienda  Calificación
# 151 2023-02-01  tienda_4      3.919355
# 154 2023-03-01  tienda_3      3.888889
# 152 2023-03-01  tienda_1      3.974026
# 153 2023-03-01  tienda_2      3.971014
# 155 2023-03-01  tienda_4      4.510204

# %% [markdown]
# ### Resultados Clave de Calificaciones promedio:
#
# *   **Consistencia de Alta Calificación**: Todas las tiendas mantienen un promedio de calificación muy similar y alto, oscilando entre aproximadamente 3.98 y 4.05 sobre 5. Esto sugiere que, en general, los clientes están satisfechos con su experiencia en todas las tiendas.
# *   **Liderazgo de Tienda 3**: La `tienda_3` presenta la calificación promedio más alta (4.05), lo que podría indicar una ligera ventaja en la satisfacción del cliente en comparación con las otras tiendas. Esto podría deberse a un servicio excepcional, calidad del producto, o una combinación de factores.
# *   **Rangos Estrechos**: La diferencia entre la calificación más alta y la más baja es mínima (aproximadamente 0.07 puntos), lo que refuerza la idea de que todas las tiendas ofrecen una experiencia de cliente consistentemente buena.

# %% [markdown]
# # 4. Productos más y menos vendidos
#
# * Objetivo: Identificar los productos más vendidos y menos vendidos en cada tienda.

# %%
top_products_data = [] #inicializamos lista para almacenar los top 5 productos
bottom_products_data = [] # inicializamos lista para almacenar los 5 productos menos vendidos

for i, tienda_df in enumerate([tienda_1, tienda_2, tienda_3, tienda_4]):
    store_name = f'tienda_{i+1}'
    # Contar la frecuencia de cada producto
    product_counts = tienda_df['Producto'].value_counts().reset_index()
    product_counts.columns = ['Producto', 'Cantidad de Ventas']

    # Seleccionar los 5 productos más vendidos
    top_5_products = product_counts.head(5).copy()
    top_5_products.loc[:, 'Tienda'] = store_name
    top_5_products.loc[:, 'Tipo'] = 'Más Vendidos'
    top_products_data.append(top_5_products)

    # Seleccionar los 5 productos menos vendidos
    bottom_5_products = product_counts.tail(5).copy()
    bottom_5_products.loc[:, 'Tienda'] = store_name
    bottom_5_products.loc[:, 'Tipo'] = 'Menos Vendidos'
    bottom_products_data.append(bottom_5_products)

# Concatenar todos los DataFrames de productos principales (needed for visualization cell)
all_top_products_df = pd.concat(top_products_data, ignore_index=True)
all_bottom_products_df = pd.concat(bottom_products_data, ignore_index=True)

# Mostrar los top 5 productos más vendidos por tienda
print("--- Top 5 Productos Más Vendidos por Tienda ---")
for df in top_products_data:
    store_name = df['Tienda'].iloc[0]
    print(f"\n--- {store_name} (Más Vendidos) ---")
    display(df[['Producto', 'Cantidad de Ventas']])
# Mostrar los 5 productos menos vendidos por tienda
print("\n--- Top 5 Productos Menos Vendidos por Tienda ---")
for df in bottom_products_data:
    store_name = df['Tienda'].iloc[0]
    print(f"\n--- {store_name} (Menos Vendidos) ---")
    display(df[['Producto', 'Cantidad de Ventas']])
# Out:
# --- Top 5 Productos Más Vendidos por Tienda ---
#
# --- tienda_1 (Más Vendidos) ---
#                   Producto  Cantidad de Ventas
# 0            TV LED UHD 4K                  60
# 1                  Armario                  60
# 2               Microondas                  60
# 3         Secadora de ropa                  58
# 4  Bloques de construcción                  56
# --- tienda_2 (Más Vendidos) ---
#                     Producto  Cantidad de Ventas
# 0  Iniciando en programación                  65
# 1                 Microondas                  62
# 2                    Batería                  61
# 3          Guitarra acústica                  58
# 4                  Pandereta                  58
# --- tienda_3 (Más Vendidos) ---
#           Producto  Cantidad de Ventas
# 0    Kit de bancas                  57
# 1        Cama king                  56
# 2  Mesa de comedor                  56
# 3     Set de ollas                  55
# 4    Mesa de noche                  55
# ...

# %%
for top_df, bottom_df in zip(top_products_data, bottom_products_data):

    store_name = top_df['Tienda'].iloc[0]

    fig, axes = plt.subplots(1, 2, figsize=(12, 4), sharex=False)

    # -------- TOP 5 --------
    axes[0].barh(
        top_df['Producto'],
        top_df['Cantidad de Ventas']
    )
    axes[0].invert_yaxis()
    axes[0].set_title(f"Top 5 Más Vendidos – {store_name}")
    axes[0].set_xlabel("Cantidad de Ventas")
    axes[0].grid(axis='x', linestyle='--', alpha=0.6)

    # -------- BOTTOM 5 --------
    axes[1].barh(
        bottom_df['Producto'],
        bottom_df['Cantidad de Ventas']
    )
    #axes[1].invert_yaxis()
    axes[1].set_title(f"Top 5 Menos Vendidos – {store_name}")
    axes[1].set_xlabel("Cantidad de Ventas")
    axes[1].grid(axis='x', linestyle='--', alpha=0.6)

    # Título general
    fig.suptitle(
        f"Top Ventas por Tiendas: {store_name}",
        fontsize=13,
        fontweight='bold'
    )

    plt.tight_layout()
    plt.savefig(f"imgs/top_bottom_products_{store_name}.png")
    plt.show()

# %% [markdown]
# ## Resultados Clave por Tienda:
#
# *   **Tienda 1**: 'TV LED UHD 4K', 'Armario' y 'Microondas' (60 ventas). Tiene una buena presencia de productos de oficina y electrodomésticos.
#
# *   **Tienda 2**: 'Iniciando en programación' (65 ventas) es el producto estrella, seguido por 'Microondas' (62), 'Batería' (61) lideran las ventas.
#
# *   **Tienda 3**: 'Kit de bancas' (57 ventas), seguido de 'Cama king' (56), 'Mesa de comedor' (56). Predominan los muebles y artículos de hogar.
#
# *   **Tienda 4**: 'Cama box' (62 ventas) es el producto más vendido, seguido de 'Cubertería' (59), 'Dashboards con Power BI' (56), 'Cama king' (56) y 'Mesa de noche' (55). Notable presencia de productos tecnológicos/educativos.
#
# **Además**:
#
# Instrumentos musicales (guitarras, pandereta) aparecen consistentemente entre los menos vendidos,
# Productos de Librería como "Ciencia de datos con Python" tienen baja demanda en tiendas 1 y 4. El comportamiento varía por tienda: "Mesa de comedor" es top en tienda 3, pero entre los peores en tienda 2.

# %% [markdown]
# # 5. Envío promedio por tienda
#
# * Objetivo: calcular el costo de envío promedio para cada tienda.

# %%
average_shipping_cost = {}
for i, tienda_df in enumerate([tienda_1, tienda_2, tienda_3, tienda_4]):
    store_name = f'tienda_{i+1}'
    average_shipping_cost[store_name] = tienda_df['Costo de envío'].mean().round(2)

average_shipping_cost_df = pd.DataFrame(list(average_shipping_cost.items()), columns=['Tienda', 'Costo de Envío Promedio'])

print("Costo de Envío Promedio por Tienda:")
display(average_shipping_cost_df)
# Out:
# Costo de Envío Promedio por Tienda:
#      Tienda  Costo de Envío Promedio
# 0  tienda_1                 26018.61
# 1  tienda_2                 25216.24
# 2  tienda_3                 24805.68
# 3  tienda_4                 23459.46

# %%
custom_palette = [
    "#E85D3A",  # Naranja  más alto promedio  
    "#3A62E4",  # Azul promedio
    "#3ABFE4", # Azul claro promedio
    "#BAE43A"  # Verde  más bajo promedio
        
    
]

plt.figure(figsize=(10, 6))
sns.barplot(x='Tienda', y='Costo de Envío Promedio', data=average_shipping_cost_df, palette=custom_palette, hue='Tienda', legend=False)
plt.title('Costo de Envío Promedio por Tienda', fontsize=16)
plt.xlabel('Tienda', fontsize=12)
plt.ylabel('Costo de Envío Promedio', fontsize=12)
plt.ticklabel_format(style='plain', axis='y') # Para evitar notación científica
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Añadir etiquetas de valor en las barras
for index, row in average_shipping_cost_df.iterrows():
    plt.text(index, row['Costo de Envío Promedio'], f'{row['Costo de Envío Promedio']:.2f}', color='black', ha="center", va='bottom')
plt.savefig('imgs/costo_envio_promedio_tienda.png')
plt.show()

# %% [markdown]
# ## Tendencia de Costo de envío promedio de los últimos 12 meses

# %%
costo_envio_mensual = df_consolidado.groupby(['Mes-Año', 'Tienda'])['Costo de envío'].mean().reset_index()

costo_envio_mensual['Mes-Año'] = pd.to_datetime(costo_envio_mensual['Mes-Año'])
costo_envio_mensual = costo_envio_mensual.sort_values(by='Mes-Año')

# Filter for the last 12 unique months
latest_month = costo_envio_mensual['Mes-Año'].max()
start_date_12_months = latest_month - pd.DateOffset(months=11) # To include the latest month, we go back 11 months
costo_envio_mensual_last_12 = costo_envio_mensual[costo_envio_mensual['Mes-Año'] >= start_date_12_months]

plt.figure(figsize=(14, 7))
sns.lineplot(data=costo_envio_mensual_last_12, x='Mes-Año', y='Costo de envío', hue='Tienda', marker='o')
plt.title('Tendencia de Costo de Envío Promedio Mensual por Tienda (Últimos 12 Meses)', fontsize=16)
plt.xlabel('Mes-Año', fontsize=12)
plt.ylabel('Costo de Envío Promedio', fontsize=12)
plt.ticklabel_format(style='plain', axis='y') # Evitar notación científica
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend(title='Tienda')
plt.tight_layout()
plt.savefig('imgs/Tendencia_Costo_emvio_promedio_12m')
plt.show()

print("DataFrame de costo de envío promedio mensual (últimos 12 meses):")
display(costo_envio_mensual_last_12.head())
# Out:
# DataFrame de costo de envío promedio mensual (últimos 12 meses):
#        Mes-Año    Tienda  Costo de envío
# 108 2022-04-01  tienda_1    17522.058824
# 109 2022-04-01  tienda_2    31174.576271
# 110 2022-04-01  tienda_3    26351.724138
# 111 2022-04-01  tienda_4    18237.096774
# 114 2022-05-01  tienda_3    30200.000000

# %% [markdown]
# ## Resultados clave en costos de envío promedio:
#
# *   **Tienda 1 con el Mayor Costo Promedio**: La `tienda_1` presenta el costo de envío promedio más alto (aproximadamente 26,018), lo cual podría estar relacionado con su mayor volumen de ventas y facturación. Un mayor volumen podría implicar una mayor distribución a zonas con costos variables, o simplemente que los productos más caros también tienen costos de envío más altos.
# *   **Tienda 4 con el Menor Costo Promedio**: La `tienda_4` tiene el costo de envío promedio más bajo (aproximadamente 23,459). Esto podría ser un indicio de una logística más eficiente, un enfoque en productos con menores requisitos de envío, o un menor alcance geográfico de sus envíos.

# %% [markdown]
# ## Informe de Resultados
#
#
# 1. **Análisis de facturación**
#
#    **Resultados:**
#
#    * **Tienda 1:** 1 212 258 300.00
#    * **Tienda 2:** 1 175 828 600.00
#    * **Tienda 3:** 1 156 536 200.00
#    * **Tienda 4:** 1 093 693 100.00
#
#    **Insight:** La *Tienda 1* lidera la facturación total del ecosistema, superando a la Tienda 4 en más de **118 millones**, lo que evidencia una ventaja competitiva clara en volumen de ventas o ticket promedio.
#
# 2. **Ventas por categoría**
#
#    * Identificación de categorías con mayor volumen de ventas.
#    * Comparación del desempeño por tienda.
#
#    **Resultados (ventas totales):**
#
#    * **Muebles:** 1,886 (categoría líder)
#    * **Electrónicos:** 1,772
#    * **Juguetes:** 1,290
#    * **Electrodomésticos:** 1,149
#    * **Deportes y diversión:** 1,113
#    * **Instrumentos musicales:** 753
#    * **Libros:** 742
#    * **Artículos para el hogar:** 730 (menor volumen)
#
#    **Insight:** Las categorías **Muebles** y **Electrónicos** concentran la mayor parte de la demanda, representando el núcleo del negocio. Las categorías con menor volumen podrían potenciarse mediante promociones y estrategias de marketing.
#
# 3. **Calificación promedio de la tienda**
#
#    * Evaluación de la satisfacción de los clientes.
#
#    **Resultados:**
#
#    * **Tienda 1:** 3.98
#    * **Tienda 2:** 4.04
#    * **Tienda 3:** 4.05 (mejor calificada)
#    * **Tienda 4:** 4.00
#
#    **Insight:** Aunque la *Tienda 3* es la mejor valorada por los clientes, no es la líder en facturación, lo que sugiere una oportunidad para escalar ventas manteniendo la alta satisfacción.
#
# 4. **Productos más y menos vendidos**
#
#    * Identificación de patrones de demanda.
#
#    **Productos destacados:**
#
#    * Producto más vendido Tienda 1: *TV LED UHD 4K* (60 ventas)
#    * Producto más vendido Tienda 2: *Iniciando en programación* (65 ventas)
#    * Producto más vendido Tienda 3: *Kit de bancas* (57 ventas)
#    * Producto más vendido Tienda 4: *Cama box* (62 ventas)
#
#    **Insight:** Los productos líderes varían por tienda, lo que confirma estrategias de catálogo diferenciadas.
#
# 5. **Costo de envío promedio**
#
#    * Análisis del impacto logístico en cada tienda.
#
#    **Resultados:**
#
#    * **Tienda 1:** 26,018.61
#    * **Tienda 2:** 25,216.24
#    * **Tienda 3:** 24,805.68
#    * **Tienda 4:** 23,459.46 (menor costo)
#
#    **Insight:** La *Tienda 4* presenta la mayor eficiencia logística. Optimizar costos de envío en otras tiendas podría mejorar márgenes y competitividad.
#
#
#
# 8. **Conclusiones**
#
#    El análisis integral muestra que ninguna tienda presenta un desempeño crítico que justifique su venta o cierre. Todas aportan valor al ecosistema de Alura Stores, ya sea por facturación, satisfacción del cliente o eficiencia logística. Las diferencias observadas representan **oportunidades de optimización**, no señales de descarte.
#
# ---
#
# ## Recomendaciones estratégicas
#
# En base a los resultados obtenidos, **no se recomienda vender ni descartar ninguna tienda**. En su lugar, se sugieren acciones específicas de mejora por tienda:
#
# ### Tienda 1 – Líder en facturación
#
# * **Fortaleza:** Mayor facturación total (1,212,258,300).
# * **Oportunidad:** Calificación promedio más baja (3.98).
# * **Acciones sugeridas:**
#
#   * Mejorar la experiencia postventa y tiempos de entrega.
#   * Analizar reseñas negativas para reducir fricciones del cliente.
#   * Mantener el mix de productos líderes en ingresos.
#
# ### Tienda 2 – Desempeño equilibrado
#
# * **Fortaleza:** Buen balance entre facturación y satisfacción (rating 4.04).
# * **Oportunidad:** No lidera en ningún indicador clave.
# * **Acciones sugeridas:**
#
#   * Potenciar los productos más vendidos (ej. *Iniciando en programación*).
#   * Optimizar costos logísticos para acercarse a la eficiencia de Tienda 4.
#
# ### Tienda 3 – Mayor satisfacción del cliente
#
# * **Fortaleza:** Mejor calificación promedio (4.05).
# * **Oportunidad:** Facturación inferior a Tienda 1 y 2.
# * **Acciones sugeridas:**
#
#   * Incrementar inversión en marketing y visibilidad.
#   * Replicar buenas prácticas de atención al cliente en otras tiendas.
#   * Ampliar stock de categorías con alta aceptación.
#
# ### Tienda 4 – Mayor eficiencia logística
#
# * **Fortaleza:** Menor costo de envío promedio (23,459.46).
# * **Oportunidad:** Menor facturación total del grupo.
# * **Acciones sugeridas:**
#
#   * Usar la ventaja logística como argumento comercial (envíos más económicos).
#   * Impulsar campañas promocionales para aumentar volumen de ventas.
#
# ### Recomendación Estratégica
# Se recomienda **mantener las cuatro tiendas operativas**, implementando una estrategia de mejora continua basada en:
#
# * Optimización logística.
# * Mejora de experiencia del cliente.
# * Enfoque en categorías y productos líderes.
#
# * Una decisión final sobre la tienda con menor rendimiento (tienda_4) debería sopesar factores 'intangibles' que podrían revelar un valor oculto o un potencial no reflejado en las métricas actuales.
#
# Esta estrategia permite **incrementar el rendimiento global sin incurrir en los costos y riesgos asociados a la venta o cierre de tiendas**.
#
# ---
#
# *Autor: Lennin Billey Temoche Gómez*
